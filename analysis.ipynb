# %%
#imports
import numpy as np
import pandas as pd
from Perceptron import Perceptron
import dataGenerator as dg
import plotGenerator as pg
import training as tr
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#set global aesthetics and context
sns.set_theme(style='darkgrid', context={'font.size': 18, 'lines.linewidth':2.5}, palette='deep', font="sans-serif", font_scale=1.2, rc={'axes.grid': True, 'xtick.bottom': True, 'axes.labelsize':16})

# %%
data = dg.createData(0,100,100,2,bias=1)
data['clf'] = np.where(data.d1 > data.d2, 1, -1)

# %%
pg.plot2d(data,15,6)

# %%
p = Perceptron(2, 0.001)
p.getWeights()
# Out:
# [0.24106574831851812, 0.7577739307312626, 0.11339671417377395]

# %%
columns = ['d1', 'd2', 'bias']
p = tr.roundTrain(data,p,columns)
# Out:
# [0.24106574831851812, 0.7577739307312626, 0.11339671417377395]
# [0.24106574831851812, 0.7577739307312626, 0.11339671417377395]
# [0.24106574831851812, 0.7577739307312626, 0.11339671417377395]
# [0.24106574831851812, 0.7577739307312626, 0.11339671417377395]
# [0.18306574831851813, 0.6657739307312627, 0.11139671417377395]
# [-0.006934251681481873, 0.46777393073126267, 0.10939671417377395]
# [-0.1809342516814819, 0.28177393073126267, 0.10739671417377394]
# [-0.2689342516814819, 0.15777393073126267, 0.10739671417377394]
# [-0.2689342516814819, 0.15777393073126267, 0.10739671417377394]
# [-0.2689342516814819, 0.15777393073126267, 0.10739671417377394]
# [-0.3369342516814819, 0.009773930731262676, 0.10739671417377394]
# [-0.3369342516814819, 0.009773930731262676, 0.10739671417377394]
# [-0.3369342516814819, 0.009773930731262676, 0.10739671417377394]
# [-0.23493425168148188, 0.06377393073126267, 0.10939671417377395]
# [-0.11893425168148188, 0.15177393073126266, 0.11139671417377395]
# ...
